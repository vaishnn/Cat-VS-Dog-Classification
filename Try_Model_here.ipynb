# %%
import h5py
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
a = tf.keras.models.load_model("Model.h5")
import cv2
def is_this_a_cat_or_a_dog(path):
    #reading the image from path
    im = cv2.imread(path)
    #reshaping image for inputting in tensor flow
    reshaped_im =  tf.reshape(cv2.resize(im,(200,200)),[1,200,200,3])
    Var = a.predict(reshaped_im)
    print(Var)
    #Checking if it's resemble to cat or not
    if Var >= 0.5:
        print("It's a Cat")
    else:
        print("It's a dog")
is_this_a_cat_or_a_dog("brown-dog-names-cover-image.jpg")
plt.imshow(cv2.imread("brown-dog-names-cover-image.jpg"))
# Out:
# 1/1 [==============================] - 0s 101ms/step
# [[0.]]
# It's a dog

# %% [markdown]
# ## for testing Yourself
# Enter this in next Cell
# <br><br>
# <font color = "grey">
# is_this_a_cat_or_a_dog(#Enter Image Directory here) <br>
# plt.imshow(cv2.imread(#Enter Image Directory here))
# </font>
